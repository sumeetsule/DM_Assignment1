# %%
import os
import xml.etree.ElementTree as ET
from PIL import Image

# Cropping and resizing the images for Golden retriever Data set (Data set 1)
# Step 1: Load the Annotations Dataset (Assuming XML format)
annotations_dir = 'D:\Dataset\Golden Retriever annonations\\n02099601-golden_retriever'  # Replace with the path to your Annotations dataset
annotations_files = os.listdir(annotations_dir)

# Step 2: Load the Images Dataset
images_dir = 'D:\Dataset\Golden Retrieverpng'  # Replace with the path to your 4-class Images dataset
output_dir = 'D:\Dataset\Golden Retriever cropped'  # Directory to save cropped and resized images

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Step 3: Parse XML Data and Crop & Resize Images
for xml_file in annotations_files:
    xml_path = os.path.join(annotations_dir, xml_file)
    image_filename = os.path.splitext(xml_file)[0] + '.png'  # Assuming image filenames correspond to XML files
    image_path = os.path.join(images_dir, image_filename)

    if os.path.exists(image_path):
        tree = ET.parse(xml_path)
        root = tree.getroot()

        # Extract bounding box coordinates
        xmin = int(root.find(".//xmin").text)
        ymin = int(root.find(".//ymin").text)
        xmax = int(root.find(".//xmax").text)
        ymax = int(root.find(".//ymax").text)

        # Load and crop the image
        image = Image.open(image_path)
        cropped_image = image.crop((xmin, ymin, xmax, ymax))

        # Resize the cropped image to 100x100 pixels
        resized_image = cropped_image.resize((100, 100), Image.ANTIALIAS)

        # Save the resized image as PNG
        output_path = os.path.join(output_dir, image_filename)
        resized_image.save(output_path, "PNG")

        print(f"Processed: {image_filename}")

print("All images processed and saved.")


# Cropping and resizing the images for Beagle Data set (Data set 2)
# Step 1: Load the Annotations Dataset (Assuming XML format)
annotations_dir = 'D:\Dataset\Beagle annonations\\n02088364-beagle'  # Replace with the path to your Annotations dataset
annotations_files = os.listdir(annotations_dir)

# Step 2: Load the Images Dataset
images_dir = 'D:\Dataset\Beaglepng'  # Replace with the path to your 4-class Images dataset
output_dir = 'D:\Dataset\Beagle cropped'  # Directory to save cropped and resized images

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Step 3: Parse XML Data and Crop & Resize Images
for xml_file in annotations_files:
    xml_path = os.path.join(annotations_dir, xml_file)
    image_filename = os.path.splitext(xml_file)[0] + '.png'  # Assuming image filenames correspond to XML files
    image_path = os.path.join(images_dir, image_filename)

    if os.path.exists(image_path):
        tree = ET.parse(xml_path)
        root = tree.getroot()

        # Extract bounding box coordinates
        xmin = int(root.find(".//xmin").text)
        ymin = int(root.find(".//ymin").text)
        xmax = int(root.find(".//xmax").text)
        ymax = int(root.find(".//ymax").text)

        # Load and crop the image
        image = Image.open(image_path)
        cropped_image = image.crop((xmin, ymin, xmax, ymax))

        # Resize the cropped image to 100x100 pixels
        resized_image = cropped_image.resize((100, 100), Image.ANTIALIAS)

        # Save the resized image as PNG
        output_path = os.path.join(output_dir, image_filename)
        resized_image.save(output_path, "PNG")

        print(f"Processed: {image_filename}")

print("All images processed and saved.")


# Cropping and resizing the images for Dhole Data set (Data set 3)
# Step 1: Load the Annotations Dataset (Assuming XML format)
annotations_dir = 'D:\Dataset\Dhole annonations\\n02115913-dhole'  # Replace with the path to your Annotations dataset
annotations_files = os.listdir(annotations_dir)

# Step 2: Load the Images Dataset
images_dir = 'D:\Dataset\Dholepng'  # Replace with the path to your 4-class Images dataset
output_dir = 'D:\Dataset\Dholecropped'  # Directory to save cropped and resized images

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Step 3: Parse XML Data and Crop & Resize Images
for xml_file in annotations_files:
    xml_path = os.path.join(annotations_dir, xml_file)
    image_filename = os.path.splitext(xml_file)[0] + '.png'  # Assuming image filenames correspond to XML files
    image_path = os.path.join(images_dir, image_filename)

    if os.path.exists(image_path):
        tree = ET.parse(xml_path)
        root = tree.getroot()

        # Extract bounding box coordinates
        xmin = int(root.find(".//xmin").text)
        ymin = int(root.find(".//ymin").text)
        xmax = int(root.find(".//xmax").text)
        ymax = int(root.find(".//ymax").text)

        # Load and crop the image
        image = Image.open(image_path)
        cropped_image = image.crop((xmin, ymin, xmax, ymax))

        # Resize the cropped image to 100x100 pixels
        resized_image = cropped_image.resize((100, 100), Image.ANTIALIAS)

        # Save the resized image as PNG
        output_path = os.path.join(output_dir, image_filename)
        resized_image.save(output_path, "PNG")

        print(f"Processed: {image_filename}")

print("All images processed and saved.")



# Cropping and resizing the images for Great Pyreness Data set (Data set 3)
# Step 1: Load the Annotations Dataset (Assuming XML format)
annotations_dir = 'D:\Dataset\Great Pyreness annonations\\n02111500-Great_Pyrenees'  # Replace with the path to your Annotations dataset
annotations_files = os.listdir(annotations_dir)

# Step 2: Load the Images Dataset
images_dir = 'D:\Dataset\Great pyrenesspng'  # Replace with the path to your 4-class Images dataset
output_dir = 'D:\Dataset\Great pyreness cropped'  # Directory to save cropped and resized images

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Step 3: Parse XML Data and Crop & Resize Images
for xml_file in annotations_files:
    xml_path = os.path.join(annotations_dir, xml_file)
    image_filename = os.path.splitext(xml_file)[0] + '.png'  # Assuming image filenames correspond to XML files
    image_path = os.path.join(images_dir, image_filename)

    if os.path.exists(image_path):
        tree = ET.parse(xml_path)
        root = tree.getroot()

        # Extract bounding box coordinates
        xmin = int(root.find(".//xmin").text)
        ymin = int(root.find(".//ymin").text)
        xmax = int(root.find(".//xmax").text)
        ymax = int(root.find(".//ymax").text)

        # Load and crop the image
        image = Image.open(image_path)
        cropped_image = image.crop((xmin, ymin, xmax, ymax))

        # Resize the cropped image to 100x100 pixels
        resized_image = cropped_image.resize((100, 100), Image.ANTIALIAS)

        # Save the resized image as PNG
        output_path = os.path.join(output_dir, image_filename)
        resized_image.save(output_path, "PNG")

        print(f"Processed: {image_filename}")

print("All images processed and saved.")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3720\2072408446.py:38: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   resized_image = cropped_image.resize((100, 100), Image.ANTIALIAS)
# Processed: n02099601_10.png
# Processed: n02099601_100.png
# Processed: n02099601_1010.png
# Processed: n02099601_1028.png
# Processed: n02099601_109.png
# Processed: n02099601_1162.png
# Processed: n02099601_118.png
# Processed: n02099601_124.png
# Processed: n02099601_1249.png
# Processed: n02099601_1259.png
# Processed: n02099601_1324.png
# Processed: n02099601_14.png
# Processed: n02099601_142.png
# Processed: n02099601_1442.png
# Processed: n02099601_1454.png
# Processed: n02099601_146.png
# Processed: n02099601_1580.png
# Processed: n02099601_1633.png
# Processed: n02099601_1743.png
# Processed: n02099601_176.png
# Processed: n02099601_1768.png
# Processed: n02099601_2029.png
# Processed: n02099601_2076.png
# Processed: n02099601_215.png
# Processed: n02099601_2295.png
# Processed: n02099601_2358.png
# Processed: n02099601_2359.png
# Processed: n02099601_238.png
# Processed: n02099601_2408.png
# Processed: n02099601_2422.png
# Processed: n02099601_2440.png
# Processed: n02099601_2495.png
# Processed: n02099601_2536.png
# Processed: n02099601_2663.png
# Processed: n02099601_2688.png
# Processed: n02099601_2691.png
# Processed: n02099601_2796.png
# Processed: n02099601_280.png
# Processed: n02099601_281.png
# Processed: n02099601_286.png
# Processed: n02099601_2980.png
# Processed: n02099601_2994.png
# Processed: n02099601_3004.png
# Processed: n02099601_3007.png
# Processed: n02099601_304.png
# Processed: n02099601_3073.png
# Processed: n02099601_308.png
# Processed: n02099601_3097.png
# Processed: n02099601_3111.png
# Processed: n02099601_3202.png
# Processed: n02099601_3262.png
# Processed: n02099601_3327.png
# Processed: n02099601_3360.png
# Processed: n02099601_3388.png
# Processed: n02099601_3414.png
# Processed: n02099601_342.png
# Processed: n02099601_345.png
# Processed: n02099601_3494.png
# Processed: n02099601_3508.png
# Processed: n02099601_3569.png
# Processed: n02099601_3666.png
# Processed: n02099601_3720.png
# Processed: n02099601_3738.png
# Processed: n02099601_3853.png
# Processed: n02099601_3869.png
# Processed: n02099601_4005.png
# Processed: n02099601_4241.png
# Processed: n02099601_4256.png
# Processed: n02099601_4312.png
# Processed: n02099601_447.png
# Processed: n02099601_4651.png
# Processed: n02099601_4678.png
# Processed: n02099601_473.png
# Processed: n02099601_4843.png
# Processed: n02099601_4933.png
# Processed: n02099601_5.png
# Processed: n02099601_5051.png
# Processed: n02099601_5132.png
# Processed: n02099601_5160.png
# Processed: n02099601_5188.png
# Processed: n02099601_5240.png
# Processed: n02099601_5366.png
# Processed: n02099601_544.png
# Processed: n02099601_5452.png
# Processed: n02099601_5453.png
# Processed: n02099601_5544.png
# Processed: n02099601_5642.png
# Processed: n02099601_5655.png
# Processed: n02099601_5679.png
# Processed: n02099601_569.png
# Processed: n02099601_5709.png
# Processed: n02099601_5736.png
# Processed: n02099601_5764.png
# Processed: n02099601_5857.png
# Processed: n02099601_5876.png
# Processed: n02099601_5893.png
# Processed: n02099601_6099.png
# Processed: n02099601_6105.png
# Processed: n02099601_6139.png
# Processed: n02099601_6194.png
# Processed: n02099601_6233.png
# Processed: n02099601_6318.png
# Processed: n02099601_6331.png
# Processed: n02099601_6338.png
# Processed: n02099601_6577.png
# Processed: n02099601_67.png
# Processed: n02099601_6726.png
# Processed: n02099601_6772.png
# Processed: n02099601_6814.png
# Processed: n02099601_6820.png
# Processed: n02099601_6867.png
# Processed: n02099601_6980.png
# Processed: n02099601_70.png
# Processed: n02099601_7019.png
# Processed: n02099601_7037.png
# Processed: n02099601_704.png
# Processed: n02099601_7119.png
# Processed: n02099601_7123.png
# Processed: n02099601_7227.png
# Processed: n02099601_7304.png
# Processed: n02099601_7312.png
# Processed: n02099601_7387.png
# Processed: n02099601_7432.png
# Processed: n02099601_7437.png
# Processed: n02099601_7588.png
# Processed: n02099601_7654.png
# Processed: n02088364_6547.png
# Processed: n02088364_6611.png
# Processed: n02088364_6866.png
# Processed: n02088364_7247.png
# Processed: n02088364_7324.png
# Processed: n02088364_769.png
# Processed: n02088364_7784.png
# Processed: n02088364_7927.png
# Processed: n02088364_8443.png
# Processed: n02088364_8477.png
# Processed: n02088364_852.png
# Processed: n02088364_8572.png
# Processed: n02088364_8612.png
# Processed: n02088364_8713.png
# Processed: n02088364_876.png
# Processed: n02088364_8820.png
# Processed: n02088364_8871.png
# Processed: n02088364_9318.png
# Processed: n02088364_9520.png
# Processed: n02088364_959.png
# Processed: n02088364_9650.png
# Processed: n02088364_9652.png
# Processed: n02088364_9825.png
# Processed: n02088364_9849.png
# Processed: n02088364_9895.png
# All images processed and saved.
# C:\Users\User\AppData\Local\Temp\ipykernel_3720\2072408446.py:126: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   resized_image = cropped_image.resize((100, 100), Image.ANTIALIAS)
# Processed: n02115913_1010.png
# Processed: n02115913_1047.png
# Processed: n02115913_1060.png
# Processed: n02115913_1066.png
# Processed: n02115913_1067.png
# Processed: n02115913_1142.png
# Processed: n02115913_1188.png
# Processed: n02115913_1213.png
# Processed: n02115913_1224.png
# Processed: n02115913_1233.png
# Processed: n02115913_1244.png
# Processed: n02115913_1273.png
# Processed: n02115913_1288.png
# Processed: n02115913_1323.png
# Processed: n02115913_1332.png
# Processed: n02115913_1334.png
# Processed: n02115913_1352.png
# Processed: n02115913_139.png
# Processed: n02115913_1449.png
# Processed: n02115913_1493.png
# Processed: n02115913_1522.png
# Processed: n02115913_1552.png
# Processed: n02115913_1578.png
# Processed: n02115913_1622.png
# Processed: n02115913_1631.png
# Processed: n02115913_1637.png
# Processed: n02115913_1663.png
# Processed: n02115913_1677.png
# Processed: n02115913_1682.png
# Processed: n02115913_1688.png
# Processed: n02115913_1742.png
# Processed: n02115913_1744.png
# Processed: n02115913_1772.png
# Processed: n02115913_1796.png
# Processed: n02115913_1830.png
# Processed: n02115913_1897.png
# Processed: n02115913_1963.png
# Processed: n02115913_1979.png
# Processed: n02115913_2005.png
# Processed: n02115913_2014.png
# Processed: n02115913_2029.png
# Processed: n02115913_2044.png
# Processed: n02115913_2138.png
# Processed: n02115913_219.png
# Processed: n02115913_2253.png
# Processed: n02115913_2259.png
# Processed: n02115913_2264.png
# Processed: n02115913_2300.png
# Processed: n02115913_2320.png
# Processed: n02115913_2325.png
# Processed: n02115913_2338.png
# Processed: n02115913_2365.png
# Processed: n02115913_2412.png
# Processed: n02115913_2414.png
# Processed: n02115913_2480.png
# Processed: n02115913_25.png
# Processed: n02115913_250.png
# Processed: n02115913_2520.png
# Processed: n02115913_2524.png
# Processed: n02115913_253.png
# Processed: n02115913_2542.png
# Processed: n02115913_257.png
# Processed: n02115913_2579.png
# Processed: n02115913_262.png
# Processed: n02115913_2657.png
# Processed: n02115913_2841.png
# Processed: n02115913_2895.png
# Processed: n02115913_3010.png
# Processed: n02115913_3052.png
# Processed: n02115913_3107.png
# Processed: n02115913_311.png
# Processed: n02115913_3115.png
# Processed: n02115913_312.png
# Processed: n02115913_3178.png
# Processed: n02115913_3196.png
# Processed: n02115913_3229.png
# Processed: n02115913_3270.png
# Processed: n02115913_3278.png
# Processed: n02115913_3313.png
# Processed: n02115913_3465.png
# Processed: n02115913_3473.png
# Processed: n02115913_3480.png
# Processed: n02115913_3527.png
# Processed: n02115913_3529.png
# Processed: n02115913_359.png
# Processed: n02115913_3601.png
# Processed: n02115913_3647.png
# Processed: n02115913_368.png
# Processed: n02115913_3740.png
# Processed: n02115913_3743.png
# Processed: n02115913_3753.png
# Processed: n02115913_38.png
# Processed: n02115913_3800.png
# Processed: n02115913_3842.png
# Processed: n02115913_3850.png
# Processed: n02115913_3854.png
# Processed: n02115913_3863.png
# Processed: n02115913_3875.png
# Processed: n02115913_3878.png
# Processed: n02115913_3902.png
# Processed: n02115913_3918.png
# Processed: n02115913_3991.png
# Processed: n02115913_3994.png
# Processed: n02115913_3998.png
# Processed: n02115913_4025.png
# Processed: n02115913_4031.png
# Processed: n02115913_4032.png
# Processed: n02115913_4047.png
# Processed: n02115913_4055.png
# Processed: n02115913_4059.png
# Processed: n02115913_4082.png
# Processed: n02115913_4110.png
# Processed: n02115913_4117.png
# Processed: n02115913_4119.png
# Processed: n02115913_4128.png
# Processed: n02115913_4129.png
# Processed: n02115913_4144.png
# Processed: n02115913_4163.png
# Processed: n02115913_4179.png
# Processed: n02115913_4188.png
# Processed: n02115913_423.png
# Processed: n02115913_4266.png
# Processed: n02115913_4273.png
# Processed: n02115913_4275.png
# Processed: n02115913_4308.png
# Processed: n02115913_4313.png
# Processed: n02115913_4320.png
# Processed: n02115913_4336.png
# Processed: n02115913_44.png
# Processed: n02115913_4429.png
# Processed: n02115913_4542.png
# Processed: n02115913_520.png
# Processed: n02115913_539.png
# Processed: n02115913_5392.png
# Processed: n02115913_5418.png
# Processed: n02115913_5469.png
# Processed: n02115913_5507.png
# Processed: n02115913_5593.png
# Processed: n02115913_564.png
# Processed: n02115913_593.png
# Processed: n02115913_612.png
# Processed: n02115913_614.png
# Processed: n02115913_676.png
# Processed: n02115913_678.png
# Processed: n02115913_739.png
# Processed: n02115913_750.png
# Processed: n02115913_90.png
# Processed: n02115913_907.png
# Processed: n02115913_915.png
# Processed: n02115913_92.png
# All images processed and saved.
# Processed: n02111500_1031.png
# Processed: n02111500_1048.png
# Processed: n02111500_1050.png
# Processed: n02111500_109.png
# Processed: n02111500_1097.png
# Processed: n02111500_1149.png
# Processed: n02111500_1170.png
# Processed: n02111500_1203.png
# Processed: n02111500_1233.png
# Processed: n02111500_124.png
# Processed: n02111500_1314.png
# Processed: n02111500_1358.png
# Processed: n02111500_1474.png
# Processed: n02111500_149.png
# Processed: n02111500_1557.png
# Processed: n02111500_1576.png
# Processed: n02111500_1590.png
# C:\Users\User\AppData\Local\Temp\ipykernel_3720\2072408446.py:171: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   resized_image = cropped_image.resize((100, 100), Image.ANTIALIAS)
# Processed: n02111500_1603.png
# Processed: n02111500_1653.png
# Processed: n02111500_17.png
# Processed: n02111500_1718.png
# Processed: n02111500_1743.png
# Processed: n02111500_1777.png
# Processed: n02111500_1787.png
# Processed: n02111500_1879.png
# Processed: n02111500_1943.png
# Processed: n02111500_198.png
# Processed: n02111500_2010.png
# Processed: n02111500_2018.png
# Processed: n02111500_205.png
# Processed: n02111500_2051.png
# Processed: n02111500_2058.png
# Processed: n02111500_2066.png
# Processed: n02111500_2081.png
# Processed: n02111500_2151.png
# Processed: n02111500_2185.png
# Processed: n02111500_2209.png
# Processed: n02111500_2232.png
# Processed: n02111500_2247.png
# Processed: n02111500_2272.png
# Processed: n02111500_241.png
# Processed: n02111500_2491.png
# Processed: n02111500_250.png
# Processed: n02111500_2522.png
# Processed: n02111500_2572.png
# Processed: n02111500_2596.png
# Processed: n02111500_26.png
# Processed: n02111500_260.png
# Processed: n02111500_2617.png
# Processed: n02111500_265.png
# Processed: n02111500_2651.png
# Processed: n02111500_2668.png
# Processed: n02111500_2736.png
# Processed: n02111500_2746.png
# Processed: n02111500_2747.png
# Processed: n02111500_2863.png
# Processed: n02111500_287.png
# Processed: n02111500_2905.png
# Processed: n02111500_297.png
# Processed: n02111500_300.png
# Processed: n02111500_3011.png
# Processed: n02111500_3052.png
# Processed: n02111500_3077.png
# Processed: n02111500_3095.png
# Processed: n02111500_31.png
# Processed: n02111500_32.png
# Processed: n02111500_3200.png
# Processed: n02111500_3254.png
# Processed: n02111500_3276.png
# Processed: n02111500_3306.png
# Processed: n02111500_3333.png
# Processed: n02111500_337.png
# Processed: n02111500_3513.png
# Processed: n02111500_3548.png
# Processed: n02111500_3560.png
# Processed: n02111500_3597.png
# Processed: n02111500_3672.png
# Processed: n02111500_3710.png
# Processed: n02111500_3746.png
# Processed: n02111500_3749.png
# Processed: n02111500_3835.png
# Processed: n02111500_3863.png
# Processed: n02111500_389.png
# Processed: n02111500_395.png
# Processed: n02111500_409.png
# Processed: n02111500_4097.png
# Processed: n02111500_4104.png
# Processed: n02111500_4147.png
# Processed: n02111500_4187.png
# Processed: n02111500_4315.png
# Processed: n02111500_4320.png
# Processed: n02111500_4358.png
# Processed: n02111500_4466.png
# Processed: n02111500_459.png
# Processed: n02111500_4590.png
# Processed: n02111500_4636.png
# Processed: n02111500_4678.png
# Processed: n02111500_4687.png
# Processed: n02111500_4696.png
# Processed: n02111500_4731.png
# Processed: n02111500_474.png
# Processed: n02111500_4758.png
# Processed: n02111500_4851.png
# Processed: n02111500_4854.png
# Processed: n02111500_4908.png
# Processed: n02111500_4950.png
# Processed: n02111500_499.png
# Processed: n02111500_4993.png
# Processed: n02111500_5004.png
# Processed: n02111500_5042.png
# Processed: n02111500_5043.png
# Processed: n02111500_5052.png
# Processed: n02111500_5057.png
# Processed: n02111500_5059.png
# Processed: n02111500_5104.png
# Processed: n02111500_5137.png
# Processed: n02111500_514.png
# Processed: n02111500_5225.png
# Processed: n02111500_5278.png
# Processed: n02111500_533.png
# Processed: n02111500_5346.png
# Processed: n02111500_5500.png
# Processed: n02111500_5525.png
# Processed: n02111500_5546.png
# Processed: n02111500_5599.png
# Processed: n02111500_5618.png
# Processed: n02111500_5675.png
# Processed: n02111500_5750.png
# Processed: n02111500_577.png
# Processed: n02111500_5801.png
# Processed: n02111500_5812.png
# Processed: n02111500_5826.png
# Processed: n02111500_5897.png
# Processed: n02111500_5935.png
# Processed: n02111500_5962.png
# Processed: n02111500_6045.png
# Processed: n02111500_6227.png
# Processed: n02111500_6250.png
# Processed: n02111500_628.png
# Processed: n02111500_6289.png
# Processed: n02111500_6338.png
# Processed: n02111500_6387.png
# Processed: n02111500_6401.png
# Processed: n02111500_644.png
# Processed: n02111500_6461.png
# Processed: n02111500_648.png
# Processed: n02111500_6495.png
# Processed: n02111500_6538.png
# Processed: n02111500_655.png
# Processed: n02111500_6769.png
# Processed: n02111500_6770.png
# Processed: n02111500_6792.png
# Processed: n02111500_6835.png
# Processed: n02111500_6857.png
# Processed: n02111500_6881.png
# Processed: n02111500_7006.png
# Processed: n02111500_7080.png
# Processed: n02111500_7136.png
# Processed: n02111500_7139.png
# Processed: n02111500_7194.png
# Processed: n02111500_7202.png
# Processed: n02111500_7218.png
# Processed: n02111500_7229.png
# Processed: n02111500_7304.png
# Processed: n02111500_7324.png
# Processed: n02111500_7380.png
# Processed: n02111500_7387.png
# Processed: n02111500_7398.png
# Processed: n02111500_7420.png
# Processed: n02111500_7444.png
# Processed: n02111500_7483.png
# Processed: n02111500_7495.png
# Processed: n02111500_7583.png
# Processed: n02111500_7591.png
# Processed: n02111500_7655.png
# Processed: n02111500_767.png
# Processed: n02111500_7725.png
# Processed: n02111500_7770.png
# Processed: n02111500_7935.png
# Processed: n02111500_7937.png
# Processed: n02111500_7983.png
# Processed: n02111500_7987.png
# Processed: n02111500_8042.png
# Processed: n02111500_8166.png
# Processed: n02111500_8174.png
# Processed: n02111500_8178.png
# Processed: n02111500_8209.png
# Processed: n02111500_8319.png
# Processed: n02111500_8382.png
# Processed: n02111500_8397.png
# Processed: n02111500_855.png
# Processed: n02111500_8575.png
# Processed: n02111500_8610.png
# Processed: n02111500_8637.png
# Processed: n02111500_870.png
# Processed: n02111500_8721.png
# Processed: n02111500_8729.png
# Processed: n02111500_882.png
# Processed: n02111500_8867.png
# Processed: n02111500_8884.png
# Processed: n02111500_8915.png
# Processed: n02111500_9000.png
# Processed: n02111500_9003.png
# Processed: n02111500_9015.png
# Processed: n02111500_9018.png
# Processed: n02111500_9116.png
# Processed: n02111500_9250.png
# Processed: n02111500_9264.png
# Processed: n02111500_9298.png
# Processed: n02111500_9306.png
# Processed: n02111500_9420.png
# Processed: n02111500_9423.png
# Processed: n02111500_956.png
# All images processed and saved.
